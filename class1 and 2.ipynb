# %%
print('Hello')
# Out:
# Hello

# %%
print('WARDAH')
# Out:
# WARDAH

# %%
print(5+2)
# Out:
# 7

# %%
print(5*2)
# Out:
# 10

# %%
print(5/2)
# Out:
# 2.5

# %%
print(5**2)
# Out:
# 25

# %%
print(5//2)
# Out:
# 2

# %%
print(11%3)
# Out:
# 2

# %%
name = "wardah"
school  = "PIAIC"
batch = 36
teacher = "MUHAMMAD QASIM"
timing = "9am to 12pm"
print(name)
print(school)
print(batch)
print(teacher)
print(timing)
# Out:
# wardah
# PIAIC
# 36
# MUHAMMAD QASIM
# 9am to 12pm

# %%
name = "wardah"
type(name)
# Out:
# str

# %%
name = "wardah"
print(type(name))
# Out:
# <class 'str'>

# %%
name = "wardah"
id(name)
# Out:
# 1377155646512

# %%
name = "wardah"
print(id(name))
# Out:
# 1377155646512

# %%
name = "wardah"
type(name)
id(name)
# Out:
# 1377155646512

# %%
name = "wardah"
print(type(name))
print(id(name))
# Out:
# <class 'str'>
# 1377155646512

# %%
name = "wardah"
print(len(name))
# Out:
# 6

# %%
###### give same id's because same value in different variables ########
name = "wardah"
name1 = "wardah"
print(id(name))
print(id(name1))
# Out:
# 1377155646512
# 1377155646512
